, 131, 130, 129, 129, 129, 130, 129, 127, 127, 129, 130, 131, 129, 129, 130, 132, 132, 130, 129, 128, 129, 129, 128, 128, 130, 131, 130, 129, 128, 129, 129, 129, 129, 130, 131, 129, 127, 127, 128, 130, 131, 132, 132, 129, 129, 130, 130, 130, 128, 128, 129, 130, 130, 130, 129, 130, 130, 130, 130, 130, 131, 131, 130, 128, 129, 131, 131, 135, 133, 127, 128, 128, 128, 128, 129, 131, 132, 129, 127, 128, 131, 131, 130, 131, 131, 129, 129, 127, 129, 131, 132, 134, 131, 132, 134, 134, 129, 131, 130, 128, 130, 130, 131, 130, 130, 131, 132, 130, 129, 128, 131, 131, 130, 131, 132, 132, 133, 131, 128, 129, 130, 129, 129, 128, 129, 129, 131, 131, 131, 131, 132, 130, 129, 129, 128, 131, 131, 129, 129, 131, 131, 132, 131, 130, 129, 131, 131, 131, 130, 130, 131, 130, 129, 130, 131, 131, 131, 131, 129, 130, 131, 130, 129, 129, 131, 130, 131, 129, 130, 128, 129, 131, 130, 126, 128, 129, 129, 128, 128, 131, 133, 129, 126, 126, 127])

pathes = [r"sample_2\EMG\ ", r"sample_2\random\ ", r"sample_2\harmonic\ "]
signals_EMG = []
signals_random = []
signals_harmonic = []

for path in pathes:
    for i in range(6):
        file = open(path[:-1] + str(i) + ".txt")
        dick = {'EMG' : signals_EMG, 'random' : signals_random, 'harmonic' : signals_harmonic}
        arr = np.array(file.read().split(), dtype='uint8')
        dick[path[9:-2]].append(arr)
        
signals_EMG.append(signal_test)

# %%
fig, ax = plt.subplots(3, 2, figsize=(30, 30))
ax[0, 0].tick_params(axis='both', which='major', labelsize=16)
ax[1, 0].tick_params(axis='both', which='major', labelsize=16)
ax[2, 0].tick_params(axis='both', which='major', labelsize=16)
ax[0, 1].tick_params(axis='both', which='major', labelsize=16)
ax[1, 1].tick_params(axis='both', which='major', labelsize=16)
ax[2, 1].tick_params(axis='both', which='major', labelsize=16)

def getX(sig):
    N = sig.size
    return rfftfreq(N, 1 / 256)[1:]

def getY(sig):
    yf = rfft(sig)
    return np.abs(yf)[1:]

num = 5

ax[0, 0].set_title('Сигнал', fontsize=30)
ax[0, 1].set_title('Преобразование Фурье', fontsize=30)

ax[0, 0].plot(signal_test)
ax[1, 0].plot(signals_random[num])
ax[2, 0].plot(signals_harmonic[num])

XfurieEMG, YfurieEMG = getX(signals_EMG[num]), getY(signals_EMG[num])
XfurieRandom, YfurieRandom = getX(signals_random[num]),   getY(signals_random[num])
XfurieHarmonic, YfurieHarmonic = getX(signals_harmonic[num]), getY(signals_harmonic[num])

splitSum = 50

ax[0, 1].plot(getY(signal_test))
ax[1, 1].plot(YfurieRandom[:50])
ax[2, 1].plot(YfurieHarmonic[:])

def classify(sig):
    if sum(sig[100:]) < 40000:
        return 'Harmonic'
    elif sum(sig[:50]) > 30000:
        return "Random"
    elif sum(sig[:50]) < 30000:
        return "EMG"

print("Random:   ", classify(signal_test))
print("Harmonic: ", classify(YfurieHarmonic))
print("EMG:      ", classify(YfurieEMG))
# Out:
# Random:    EMG
# Harmonic:  Harmonic
# EMG:       EMG

# %%
# XfurieEMG[:],      
# XfurieRandom[:],   
# XfurieHarmonic[:],
