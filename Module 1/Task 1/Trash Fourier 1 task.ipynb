14, 19, 29, 43, 61, 82, 103, 125, 146, 164, 179, 189, 195, 196, 192, 183, 170, 153, 135, 115, 95, 77, 61, 49, 41, 38, 40, 48, 60, 76, 95, 116, 138, 159, 179, 196, 210, 219, 223, 221, 215, 205, 190, 172, 153, 133, 114, 96, 82, 71, 65, 64, 68, 77, 91, 108, 128, 149, 171, 191, 210, 225, 237, 243, 245, 241, 233, 220, 204, 185, 165, 145, 125, 108, 95, 86, 81, 82, 87, 98, 112, 130, 150, 171, 192, 211, 228, 242, 250])

# %%
# plt.figure(figsize=(20, 10))

# v1 = 10 # find 1 < v1 < 11 v1, v1 ∈ {N}
# a2 = 42 # find ≥50
# v2 = 1 # const
# ф1 = 0
# ф2 = 1.33

# f1 = lambda t: a2 * 2 * np.sin(2 * math.pi * t * v1 + ф1) # ф1
# f2 = lambda t: a2 *     np.sin(2 * math.pi * t * 1 + ф2) # ф2

# x = np.linspace(0, 2, 100000)

# plt.tick_params(axis='both', which='major', labelsize=16)


# # plt.plot(x, (np.arcsin(f1(x) / a2 / 2) - ф1) / 2 / pi / x)
# # plt.plot(x, f2(x))
# plt.plot(x, f1(x) + f2(x))

# %%
# plt.figure(figsize=(20, 10))
# np.set_printoptions(suppress=True)
# plt.tick_params(axis='both', which='major', labelsize=16)

# x = np.linspace(0, numbers.size * 0.004, numbers.size)

# myNum = (numbers - 127.5)

# a2 = max(abs(myNum.min()), myNum.max())/3
# a2 = 50 if a2 < 50 else a2 
# ф1 = 0 # тупо рандом
# ф2 = 0 # подбором нашёл подходит только для конкретного случая
# sig2 = a2 * np.sin(2 * math.pi * x * 1 + ф2)
# sig1 = myNum - sig2

# plt.plot(x, myNum)
# plt.plot(x, sig2 + a2*2)
# sinusSig1 = sig1/a2/2

# sinusSig1[sinusSig1 < -1] = -1
# sinusSig1[sinusSig1 > 1] = 1
# # print(sinusSig1[sinusSig1 > 1].size + sinusSig1[sinusSig1 < -1].size)

# v1 = (np.arcsin(sinusSig1) - ф1) / 2 / pi / x

# # plt.plot(x, v1)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in true_divide

# %%
# plt.figure(figsize=(20, 10))
# np.set_printoptions(suppress=True)
# plt.tick_params(axis='both', which='major', labelsize=16)

# myNum = np.fft.fft(numbers)
# myNum.dtype

# plt.plot(myNum[1:30])
# myNum.max()
# Out:
# (64744+0j)

# %%
fig, ax = plt.subplots(2, 1, figsize=(50, 30))
ax[0].tick_params(axis='both', which='major', labelsize=35)
ax[1].tick_params(axis='both', which='major', labelsize=35)

FD = 22050 # частота дискретизации, отсчётов в секунду
# а это значит, что в дискретном сигнале представлены частоты от нуля до 11025 Гц (это и есть теорема Котельникова)
N = 2000 # длина входного массива, 0.091 секунд при такой частоте дискретизации
# сгенерируем сигнал с частотой 440 Гц длиной N
pure_sig = np.array([6.*sin(2.*pi*440.0*t/FD) for t in range(N)])
# сгенерируем шум, тоже длиной N (это важно!)
noise = np.random.uniform(-50.,50., N)
# суммируем их и добавим постоянную составляющую 2 мВ (допустим, не очень хороший микрофон попался. Или звуковая карта или АЦП)
sig = pure_sig + noise + 2.0 # в numpy так перегружена функция сложения
# вычисляем преобразование Фурье. Сигнал действительный, поэтому надо использовать rfft, это быстрее, чем fft
spectrum = rfft(sig)

# нарисуем всё это, используя matplotlib
# Сначала сигнал зашумлённый и тон отдельно
ax[0].plot(np.arange(N)/float(FD), sig) # по оси времени секунды!
ax[0].plot(np.arange(N)/float(FD), pure_sig, 'r') # чистый сигнал будет нарисован красным

ax[0].set_xlabel('Время, c', fontsize=50)
ax[0].set_ylabel('Напряжение, мВ', fontsize=50)
ax[0].set_title('Зашумлённый сигнал и тон 440 Гц', fontsize=80)
# когда закроется этот график, откроется следующий
# Потом спектр
ax[1].plot(rfftfreq(N, 1./FD), np.abs(spectrum)/N)
# rfftfreq сделает всю работу по преобразованию номеров элементов массива в герцы
# нас интересует только спектр амплитуд, поэтому используем abs из numpy (действует на массивы поэлементно)
# делим на число элементов, чтобы амплитуды были в милливольтах, а не в суммах Фурье. Проверить просто — постоянные составляющие должны совпадать в сгенерированном сигнале и в спектре
ax[1].set_xlabel('Частота, Гц', fontsize=50)
ax[1].set_ylabel('Напряжение, мВ', fontsize=50)
ax[1].set_title('Спектр', fontsize=80)
# Out:
# Text(0.5, 1.0, 'Спектр')

# %%
import cmath
plt.subplots(1, figsize=(20, 10))
plt.tick_params(axis='both', which='major', labelsize=20)

t = np.linspace(0, pi*2, 100)
A = 100000
v = 3
φ = 1

x = A * np.cos(t*v + φ)
x = A * cos(φ) * np.cos(t*v) - A * sin(φ) * np.sin(t*v) 
# Re = A * cos(ф) 
# Im = A * sin(ф)

# plt.ylim(-2, 2)
# plt.xlim(-1, 7)

# plt.plot(t, x)

X_k = np.fft.fft(x)
Re = X_k.real
Im = X_k.imag

find_ф = np.array(list(map(cmath.phase, X_k)))
find_A = np.sqrt(Im**2 + Re**2)

# plt.plot(find_ф) # ф
plt.plot(X_k.real) # A

print("A =      {}\nfind_A = {}\nxmm_A =  {}".format(A, find_A.max(), x.max()))
# Out:
# A =      100000
# find_A = 4982001.658084126
# xmm_A =  99884.81143486913

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
